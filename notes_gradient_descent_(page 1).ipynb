# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshaypahuja21/Machine-Learning-Basics/blob/master/notes_gradient_descent_(page%201).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notes Gradient descent page 1

# %%
from IPython.display import Image
display(Image('1.jpeg'))
display(Image('1s.jpeg'))
